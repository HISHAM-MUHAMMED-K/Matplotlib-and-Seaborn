# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.array([1,5])
y=np.array([2,8])

# %%
plt.plot(x,y)

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array((1,8,6,9))
y=np.array((2,6,1,4))
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-507ba7c4884d> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 x=np.array((1,8,6,9))
#       4 y=np.array((2,6,1,4))
#       5 plt.plot(x,y)
#
# TypeError: 'list' object is not callable

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 8, 6, 9])  # Use square brackets [] to create arrays
y = np.array([2, 6, 1, 4])

plt.plot(x, y)  # Plot x versus y

plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Correct usage of np.array() to create numpy arrays
x1 = np.array([1, 8, 6, 9])
y1= np.array([2, 6, 1, 4])

plt.plot(x1, y1)

plt.show()

# %%
x1 = np.array([1, 8])
y1= np.array([2, 6])
plt.plot(x1, y1,'o')

plt.show()

# %%
y1= np.array([2, 6])
plt.plot(y1)

plt.show()

# %%
x1=np.array([1,8])
x2=np.array([2,6])
y1=np.array([1,7])
y2=np.array([3,5])
plt.plot(x1,x2,y1,y2)
plt.show()

# %%
x1=np.array([1,8])
x2=np.array([2,6])
y1=np.array([1,7])
y2=np.array([3,5])
plt.plot(x1,x2,y1,y2,marker="o")
plt.show()

# %%
x1=np.array([1,8])
x2=np.array([2,6])
y1=np.array([1,7])
y2=np.array([3,5])
plt.plot(x1,x2,y1,y2,marker="*")
plt.show()

# %%
x1=np.array([1,8])
x2=np.array([2,6])
y1=np.array([1,7])
y2=np.array([3,5])
plt.plot(x1,x2,y1,y2,linestyle="dashed")
plt.show()

# %%
x1=np.array([1,8])
x2=np.array([2,6])
y1=np.array([1,7])
y2=np.array([3,5])
plt.plot(x1,x2,y1,y2,linestyle="dotted")
plt.show()

# %%
x1=np.array([1,8])
x2=np.array([2,6])
y1=np.array([1,7])
y2=np.array([3,5])
plt.plot(x1,x2,y1,y2,linewidth=7)
plt.show()

# %%
x1=np.array([1,8])
y1=np.array([1,7])
plt.plot(x1,y1,color="red")
plt.show()

# %%
x1=np.array([1, 3, 5, 6])
y1=np.array([1, 7, 6, 5])
colors=np.array(["black","blue", "yellow","red"])
plt.scatter([x1, y1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-eeec44e4df35> in <cell line: 4>()
#       2 y1=np.array([1, 7, 6, 5])
#       3 colors=np.array(["black","blue", "yellow","red"])
# ----> 4 plt.scatter([x1, y1])
#       5
#       6 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
import numpy as np
x=np.array([1,2,3,4])
y=np.array([2,3,6,7])

plt.title('new plot')
plt.grid()
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(x,y)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fa730577897f> in <cell line: 5>()
#       3 y=np.array([2,3,6,7])
#       4
# ----> 5 plt.title('new plot')
#       6 plt.grid()
#       7 plt.xlabel("x axis")
#
# NameError: name 'plt' is not defined

# %%
x=np.array([1,2,3,4])
y=np.array([2,3,6,7])
plt.grid()
plt.title('new plot')
plt.plot(x,y)

plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([2,3,6,7])
plt.grid(axis="x")
plt.title('new plot')
plt.plot(x,y)

plt.show()

# %%
x=np.array([1,5,3,4])
y=np.array([2,3,6,7])
plt.grid(axis="y")
plt.title('new plot')
plt.plot(x,y)

plt.show()

# %%
x=np.array([1,2,3])
y=np.array([10,15,20])
plt.subplot(1,2,1)
plt.plot(x,y)
a=np.array([4,5])
b=np.array([6,8])
plt.subplot(1,2,2)
plt.plot(a,b)

# %%
x=np.array([1,2,3])
y=np.array([10,15,20])
plt.subplot(2,3,1)
plt.plot(x,y)
a=np.array([4,5])
b=np.array([6,8])
plt.subplot(2,3,2)
plt.plot(a,b)
c=np.array([4,7])
d=np.array([2,8])
plt.subplot(2,3,3)
plt.plot(c,d)
e=np.array([2,7,8])
f=np.array([4,3,9])
plt.subplot(2,3,4)
plt.plot(e,f)
h=np.array([4,7])
j=np.array([7,8])
plt.subplot(2,3,5)
plt.plot(h,j)
k=np.array([7,5,9])
l=np.array([2,8,9])
plt.subplot(2,3,6)
plt.plot(k,l)

# %%
x=np.array([5,7,8,7,2,17,2,9,])
y=np.array([99,86,87,88,111,86,103,87])
z=np.array(["red","green","blue","yellow","pink","black","orange","purple"])

plt.scatter(x,y,c=z)

# %%
x=np.array([5,7,8,7,2,17,2,9,])
y=np.array([99,86,87,88,111,86,103,87])
z=np.array([0,10,20,30,40,50,60,70,])
plt.scatter(x,y,c=z,cmap="Accent")
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array([5,7,8,7,2,17,2,9,])
y=np.array([99,86,87,88,111,86,103,87])
z=np.array([0,10,20,30,40,50,60,70,])
plt.scatter(x,y,c=z,cmap="viridis")
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array([5,7,8,7,2,17,2,9,])
y=np.array([99,86,87,88,111,86,103,87])
z=np.array([0,10,20,30,40,50,60,70,])
plt.scatter(x,y,c=z,cmap="viridis")
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array([1,2,3,4,11])
y=np.array([1,2,6,9,9])
plt.scatter(x, y,alpha=0.4)
plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.show()

# %%
x="a","b","c","d"
y=10,20,30,40
plt.bar(x,y)
plt.title("bar chart")
plt.show()

# %%
x="a","b","c","d"
y=10,20,30,40
plt.barh(x,y,color="red")
plt.title("bar chart")
plt.show()

# %%
x="a","b","c","d"
y=10,20,30,40
plt.bar(x,y,width=0.3)
plt.title("bar chart")
plt.show()

# %%
import numpy as np

# %%
x=np.random.normal(170,10,250)
plt.hist(x)
# Out:
# (array([ 2.,  8., 15., 39., 47., 64., 37., 26., 10.,  2.]),
#  array([138.00480739, 143.97584813, 149.94688887, 155.91792961,
#         161.88897036, 167.8600111 , 173.83105184, 179.80209258,
#         185.77313332, 191.74417406, 197.7152148 ]),
#  <BarContainer object of 10 artists>)

# %%
x=np.array([2,4,6,8])
y=["a","b","c","d"]
plt.pie(x,labels=y)
plt.show()

# %%
x=np.array([2,4,6,8])
y=["a","b","c","d"]
plt.pie(x,labels=y,startangle=90)
plt.show()

# %%
x=np.array([2,4,6,8])
y=["a","b","c","d"]
z=[0.2,0,0,0]
plt.pie(x,labels=y,startangle=90,explode=z)
plt.show()

# %%
x=np.array([2,4,6,8])
y=["a","b","c","d"]
z=[0.2,0.3,0.1,0.4]
plt.pie(x,labels=y,startangle=90,explode=z)
plt.show()

# %%
x=np.array([2,4,6,8])
y=["a","b","c","d"]
z=[0.2,0.3,0.1,0.4]
plt.pie(x,labels=y,startangle=90,explode=z,shadow=3)
plt.show()

# %%
x=np.array([2,4,6,8])
y=["a","b","c","d"]
v=["black","orange","yellow","red"]
plt.pie(x,labels=y,startangle=90,shadow=3,colors=v)
plt.legend()
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/code/company_sales_data.csv')

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
df.tail()
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
x=df['total_profit']
y=df['month_number']
plt.plot(x,y)
plt.xlabel=("Month number")
plt.ylabel=("Total Profit")

plt.show()

# %%
x=df['total_profit']
y=df['month_number']
plt.plot(x,y,color="red",linestyle="dotted",marker="o",linewidth=3)
plt.xlabel=("Month Number")
plt.ylabel=("sold units number")
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
a=df['month_number']
b=df['facecream']
c=df['facewash']
d=df['toothpaste']
e=df['bathingsoap']
f=df['shampoo']
g=df['moisturizer']
h=df['total_units']
i=df['total_profit']

plt.plot(a,b)
plt.plot(a,c)
plt.plot(a,d)
plt.plot(a,e)
plt.plot(a,f)
plt.plot(a,g)
plt.plot(a,h)

plt.show()

# %%
x=df['toothpaste']
y=df['month_number']
plt.scatter(x,y)

# %%
x=df['facecream']
y=df['facewash']
z=df['month_number']
plt.bar([a-0.25 for a in z],x,width=0.25,align="edge")
plt.bar([a+0.25 for a in z],y,width=-0.25,align="edge")
# Out:
# <BarContainer object of 12 artists>

# %%
x=df['month_number']
y=df['bathingsoap']
plt.bar(x,y)
plt.show()

# %%
x=[150000,175000,200000,225000,250000,275000,300000,350000]
y=df['total_profit']
plt.hist(y,x)
plt.show()

# %%
x=df['month_number']
y=df['facecream'].sum(),df['facewash'].sum(),df['toothpaste'].sum(),df['bathingsoap'].sum(),df['shampoo'].sum(),df['moisturizer'].sum()

plt.pie(y)
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x=df['month_number']
y=df['bathingsoap']
z=df['facewash']
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(x,z)

# %%
a=df['month_number']
b=df['facecream']
c=df['facewash']
d=df['toothpaste']
e=df['bathingsoap']
f=df['shampoo']
g=df['moisturizer']

plt.plot([],[],linewidth=5,label="facecream")
plt.plot([],[],linewidth=5,label="facewash")
plt.plot([],[],linewidth=5,label="toothpaste")
plt.plot([],[],linewidth=5,label="bathingsoap")
plt.plot([],[],linewidth=5,label="shampoo")
plt.plot([],[],linewidth=5,label="moisturizer")

plt.stackplot(a,b,c,d,e,f,g)

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset("anagrams")

# %%
df.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
df=sns.load_dataset("car_crashes")

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
plt.scatter(df.speeding,df.alcohol)

plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("dark")
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("darkgrid")
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("white")
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("whitegrid")
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("ticks")
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.despine()
plt.show()

# %%
sns.palplot(sns.color_palette("deep",10))

# %%
sns.palplot(sns.color_palette("pastel",10))

# %%
sns.palplot(sns.color_palette("bright",10))

# %%
sns.palplot(sns.color_palette("dark",20))

# %%
print(sns.get_dataset_names)
# Out:
# <function get_dataset_names at 0x78e3f05e3d90>

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=df,x="total_bill",y="tip")
plt.plot()
plt.show()

# %%
sns.relplot(data=df,x="total_bill",y="tip",hue="day")
plt.plot()
plt.show()

# %%
sns.relplot(data=df,x="total_bill",y="tip",hue="sex",col="day",col_wrap=2)
plt.plot()
plt.show()

# %%
df=sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.displot(data=df,x="petal_length")
plt.plot()
plt.show()

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(data=df,x="embark_town",y="age")
plt.plot()
# Out:
# []

# %%
sns.barplot(data=df,x="embark_town",y="age")
sns.set_context("paper")
plt.plot()
# Out:
# []

# %%
sns.barplot(data=df,x="embark_town",y="age")
sns.set_context("notebook")
plt.plot()
# Out:
# []

# %%
sns.barplot(data=df,x="embark_town",y="age")
sns.set_context("talk")
plt.plot()
# Out:
# []

# %%
sns.barplot(data=df,x="embark_town",y="age")
sns.set_context("poster")
plt.plot()
# Out:
# []

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(data=df,x="sex",y="survived",hue="sex",palette="PuRd")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.barplot(data=df,x="sex",y="survived",hue="sex",palette="PuRd",order=["male","female"])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.barplot(data=df,x="age",y="embark_town",hue="sex",palette="PuRd",order=["male","female"],orient="h")
plt.legend()
plt.show()

# %%
sns.barplot(data=df,x="age",y="embark_town",hue="sex",palette="PuRd",order=["male","female"],orient="h")
plt.legend()
plt.show()

# %%
sns.barplot(data=df,x="sex",y="survived",hue="sex",palette="PuRd",order=["male","female"],orient="h")
plt.legend()
plt.show()

# %%
pip install --upgrade seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.1
#     Uninstalling seaborn-0.13.1:
#       Successfully uninstalled seaborn-0.13.1
# ...

# %%
plt.barh(data=df,x="age", y="survived",width=2)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-403b24b8c441> in <cell line: 1>()
# ----> 1 plt.barh(data=df,x="age", y="survived",width=2)
#       2 plt.legend()
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in barh(y, width, height, left, align, data, **kwargs)
#    2455         y, width, height=0.8, left=None, *, align='center',
#    2456         data=None, **kwargs):
# -> 2457     return gca().barh(
#    2458         y, width, height=height, left=left, align=align,
#    2459         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, data, **kwargs)
#    2647         """
#    2648         kwargs.setdefault('orientation', 'horizontal')
# ...

# %%
sns.countplot(data=df,x="class",hue="who",palette="PuRd")
sns.set_context("paper")
plt.title("class")
# Out:
# Text(0.5, 1.0, 'class')

# %%
 df=sns.load_dataset("tips")
 df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pointplot(data=df,x="day",y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.pointplot(data=df,x="time",y="total_bill",hue="smoker",palette="dark")
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.jointplot(data=df,x="total_bill",y="tip")
sns.set_style("dark")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="reg")
sns.set_style("dark")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="kde")
sns.set_style("dark")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="hex")
sns.set_style("dark")

# %%
sns.regplot(data=df,x="total_bill",y="tip",x_jitter=0.1)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=df,x="total_bill",y="tip")

# %%
sns.lmplot(data=df,x="total_bill",y="tip",hue="day")

# %%
sns.lmplot(data=df,x="total_bill",y="tip",hue="day",col="day",col_wrap=2,height=3)

# %%
sns.boxplot(data=df,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=df,x="total_bill")
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(data=df,x="day",y="total_bill",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=df,x="day",y="total_bill",hue="smoker",split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df=sns.load_dataset("flights")
df=df.pivot(index="month",columns="year",values="passengers")
print(df)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(data=df)
# Out:
# <Axes: xlabel='year', ylabel='month'>
